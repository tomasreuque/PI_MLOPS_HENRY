# %%
import pandas as pd
from pandas.io.json import json_normalize

# %%
movies = pd.read_csv("movies_dataset.csv")
movies.info()
# Out:
# C:\Users\tomas\AppData\Local\Temp\ipykernel_4132\4119993315.py:1: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   movies = pd.read_csv("movies_dataset.csv")
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
# ...

# %%
movies.head(1)
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#   release_date      revenue runtime                          spoken_languages  \
# 0   1995-10-30  373554033.0    81.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status  tagline      title  video vote_average vote_count
# 0  Released      NaN  Toy Story  False          7.7     5415.0
#
# [1 rows x 24 columns]

# %%
### Funcion extraer data anidada

import re
import pandas as pd

def extraer_datos(df, columna):
    # Función para extraer los valores de una cadena, lista o diccionario
    def extraer_valores(valor):
        if isinstance(valor, str):
            # Si es una cadena, extraer los valores con la expresión regular
            pattern = r"'name': '([^']*)'"
            coincidencias = re.findall(pattern, valor)
            return coincidencias
        elif isinstance(valor, list):
            # Si es una lista, extraer los valores de cada elemento de la lista
            valores = []
            for elemento in valor:
                if 'name' in elemento:
                    valores.append(elemento['name'])
            return valores
        elif isinstance(valor, dict):
            # Si es un diccionario, extraer los valores de la clave 'name'
            if 'name' in valor:
                return valor['name']
        return None
    
    # Aplicar la función a la columna y sobrescribir la columna
    df[columna] = df[columna].apply(extraer_valores)
    
    return df

# %%
# Aplicar la función para extraer los datos de la columna 'belongs_to_collection'
movies = extraer_datos(movies, 'belongs_to_collection')

# %%
# Mostrar el resultado
movies.head(1)
# Out:
#    adult   belongs_to_collection    budget  \
# 0  False  [Toy Story Collection]  30000000
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#   release_date      revenue runtime                          spoken_languages  \
# 0   1995-10-30  373554033.0    81.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status  tagline      title  video vote_average vote_count
# 0  Released      NaN  Toy Story  False          7.7     5415.0
#
# [1 rows x 24 columns]

# %%
# Aplicar la función para extraer los datos de la columna 'genres'
movies = extraer_datos(movies, 'genres')

# %%
movies.head(1)
# Out:
#    adult   belongs_to_collection    budget                       genres  \
# 0  False  [Toy Story Collection]  30000000  [Animation, Comedy, Family]
#
#                                homepage   id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story  862  tt0114709                en
#
#   original_title                                           overview  ...  \
# 0      Toy Story  Led by Woody, Andy's toys live happily in his ...  ...
#
#   release_date      revenue runtime                          spoken_languages  \
# 0   1995-10-30  373554033.0    81.0  [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status  tagline      title  video vote_average vote_count
# 0  Released      NaN  Toy Story  False          7.7     5415.0
#
# [1 rows x 24 columns]

# %%
movies["production_companies"].head()
# Out:
# 0       [{'name': 'Pixar Animation Studios', 'id': 3}]
# 1    [{'name': 'TriStar Pictures', 'id': 559}, {'na...
# 2    [{'name': 'Warner Bros.', 'id': 6194}, {'name'...
# 3    [{'name': 'Twentieth Century Fox Film Corporat...
# 4    [{'name': 'Sandollar Productions', 'id': 5842}...
# Name: production_companies, dtype: object

# %%
# Aplicar la función para extraer los datos de la columna "production_companies"
movies = extraer_datos(movies, 'production_companies')

# %%
movies["production_companies"].head()
# Out:
# 0                            [Pixar Animation Studios]
# 1    [TriStar Pictures, Teitler Film, Interscope Co...
# 2                       [Warner Bros., Lancaster Gate]
# 3             [Twentieth Century Fox Film Corporation]
# 4         [Sandollar Productions, Touchstone Pictures]
# Name: production_companies, dtype: object

# %%
# Aplicar la funcion para extraer los valores de "production_countries"
movies = extraer_datos(movies, "production_countries")

# %%
movies["production_countries"].head(1)
# Out:
# 0    [United States of America]
# Name: production_countries, dtype: object

# %%
# Aplicar la funcion para extraer los valores de "spoken_languages"
movies = extraer_datos(movies, "spoken_languages")

# %%
movies["spoken_languages"].head(1)
# Out:
# 0    [English]
# Name: spoken_languages, dtype: object

# %%
## Transformacion numero 2
# Rellenar los valores nulos con 0
movies['revenue'].fillna(0, inplace=True)
movies['budget'].fillna(0, inplace=True)

# %%
movies["budget"].value_counts()
# Out:
# 0           36573
# 5000000       286
# 10000000      259
# 20000000      243
# 2000000       242
#             ...
# 923             1
# 72500000        1
# 2160000         1
# 4439832         1
# 1254040         1
# Name: budget, Length: 1226, dtype: int64

# %%
# Verificar si hay valores nulos
nulos = movies.isnull().sum()

# Mostrar el resultado
print(nulos)
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      0
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
## Tranformacion numero 3

# Eliminar filas con valores nulos en 'release_date'
movies.dropna(subset=['release_date'], inplace=True)

# %%
movies["release_date"].head()
# Out:
# 0    1995-10-30
# 1    1995-12-15
# 2    1995-12-22
# 3    1995-12-22
# 4    1995-02-10
# Name: release_date, dtype: object

# %%
# Transformacion numero 4

# Extraer el año de la columna 'release_date' y guardarlos en una nueva columna 'year'
movies['release_year'] = movies['release_date'].str.split('-').str[0]

# %%
movies.head(15
            
            )
# Out:
#     adult             belongs_to_collection    budget  \
# 0   False            [Toy Story Collection]  30000000
# 1   False                              None  65000000
# 2   False       [Grumpy Old Men Collection]         0
# 3   False                              None  16000000
# 4   False  [Father of the Bride Collection]         0
# 5   False                              None  60000000
# 6   False                              None  58000000
# 7   False                              None         0
# 8   False                              None  35000000
# 9   False           [James Bond Collection]  58000000
# 10  False                              None  62000000
# 11  False                              None         0
# 12  False                [Balto Collection]         0
# 13  False                              None  44000000
# 14  False                              None  98000000
#
#                                 genres  \
# 0          [Animation, Comedy, Family]
# ...

# %%
movies["revenue"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 45379 entries, 0 to 45465
# Series name: revenue
# Non-Null Count  Dtype
# --------------  -----
# 45379 non-null  float64
# dtypes: float64(1)
# memory usage: 709.0 KB

# %%
movies["budget"].info()
# Out:
# <class 'pandas.core.series.Series'>
# Int64Index: 45379 entries, 0 to 45465
# Series name: budget
# Non-Null Count  Dtype
# --------------  -----
# 45379 non-null  object
# dtypes: object(1)
# memory usage: 709.0+ KB

# %%
# Convertir la columna 'budget' a tipo numérico
movies['budget'] = pd.to_numeric(movies['budget'], errors='coerce')

# Calcular la columna 'return' dividiendo 'revenue' entre 'budget'
movies['return'] = movies['revenue'] / movies['budget']

# %%
import numpy as np

# %%
movies["return"] = movies["return"].replace([np.inf, -np.inf], 0)

# %%
movies["return"].fillna(0, inplace=True)

# %%
movies["return"].head()
# Out:
# 0    12.451801
# 1     4.043035
# 2     0.000000
# 3     5.090760
# 4     0.000000
# Name: return, dtype: float64

# %%
## transformacion 5
cols_to_drop = ["video", "imdb_id", "original_title", "vote_count", "poster_path", "homepage"]

# %%
# Eliminar las columnas especificadas
data = movies.drop(cols_to_drop, axis=1)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45379 entries, 0 to 45465
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45379 non-null  object
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45376 non-null  float64
#  3   genres                 45379 non-null  object
#  4   id                     45379 non-null  object
#  5   original_language      45368 non-null  object
#  6   overview               44438 non-null  object
#  7   popularity             45377 non-null  object
#  8   production_companies   45379 non-null  object
#  9   production_countries   45379 non-null  object
#  10  release_date           45379 non-null  object
#  11  revenue                45379 non-null  float64
#  12  runtime                45130 non-null  float64
#  13  spoken_languages       45376 non-null  object
# ...

# %%
## transformaciones addicionales

# Convertir la columna 'release_date' a formato de fecha, manejar valores no válidos como NaT
data["release_date"] = pd.to_datetime(data["release_date"], errors="coerce")

# %%
data["release_date"].head()
# Out:
# 0   1995-10-30
# 1   1995-12-15
# 2   1995-12-22
# 3   1995-12-22
# 4   1995-02-10
# Name: release_date, dtype: datetime64[ns]

# %%
data.to_csv('archivo.csv', index=False)

# %%
### Aber si conseguimos el poster xD
movies["poster_path"].head()
# Out:
# 0    /rhIRbceoE9lR4veEXuwCC2wARtG.jpg
# 1    /vzmL6fP7aPKNKPRTFnZmiUfciyV.jpg
# 2    /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# 3    /16XOMpEaLWkrcPqSQqhTmeJuqQl.jpg
# 4    /e64sOI48hQXyru7naBFyssKFxVd.jpg
# Name: poster_path, dtype: object
